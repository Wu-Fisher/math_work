# %% [markdown]
# # lab3_2 代码部分

# %% [markdown]
# 库导入

# %%
import math
import numpy as np
import sympy as sp
import matplotlib.pyplot as plt

# %%
def RuKu(f,a,b,init,N):
    x = np.linspace(a,b,N+1)
    y = np.zeros(N+1)
    y[0] = init
    h = (b-a)/N
    xc = x[0]
    yc = y[0]
    print("打印结果保留四位小数：")
    print(f"x0 = {xc:.4f}, y0 = {yc:.4f}")
    for i in range(1,N+1):
        K1 = h*f.evalf(subs={'x':xc,'y':yc})
        K2 = h*f.evalf(subs={'x':xc+h/2,'y':yc+K1/2})
        K3 = h*f.evalf(subs={'x':xc+h/2,'y':yc+K2/2})
        K4 = h*f.evalf(subs={'x':xc+h,'y':yc+K3})
        yn = yc + (K1+2*K2+2*K3+K4)/6
        y[i] = yn
        print(f"x{i} = {round(x[i],4)},y{i} = {round(y[i],4)}")
        xc = x[i]
        yc = y[i]
        
    return x,y

# %%
def Verf(X,Y,exp):
    Y2 = [exp.evalf(subs={'x':x}) for x in X]
    
    E=0
    
    for i in range(len(X)):
        E += (Y[i]-Y2[i])**2
    E = math.sqrt(E/len(X))
    print(f"验证得到标准差为 = {E}")

    print("作图分析误差：")
    plt.scatter(X,Y,label="RUBU")
    plt.plot(X,Y2,'r',label='REAL')
    plt.legend()
    plt.show()

    return E

# %%
x , y =sp.symbols('x,y')
f =(2/x)*y + (x**2)*sp.exp(x)
a = 1
b = 3 
init = 0
exp = (x**2)*(sp.exp(x)-sp.E)
for n in [5,10,20]:
    print("N = ",n)
    X,Y = RuKu(f,a,b,init,n)
    E = Verf(X,Y,exp)
# Out:
# N =  5
# 打印结果保留四位小数：
# x0 = 1.0000, y0 = 0.0000
# x1 = 1.4,y1 = 2.6139
# x2 = 1.8,y2 = 10.7763
# x3 = 2.2,y3 = 30.4917
# x4 = 2.6,y4 = 72.5856
# x5 = 3.0,y5 = 156.2252
# 验证得到标准差为 = 0.042274488139714364
# 作图分析误差：
# N =  10
# 打印结果保留四位小数：
# x0 = 1.0000, y0 = 0.0000
# x1 = 1.2,y1 = 0.8664
# x2 = 1.4,y2 = 2.6197
# x3 = 1.6,y3 = 5.7199
# x4 = 1.8,y4 = 10.792
# x5 = 2.0,y5 = 18.6809
# x6 = 2.2,y6 = 30.5216
# x7 = 2.4,y7 = 47.8324
# x8 = 2.6,y8 = 72.6345
# x9 = 2.8,y9 = 107.6089
# x10 = 3.0,y10 = 156.2983
# 验证得到标准差为 = 0.003559349483814527
# 作图分析误差：
# N =  20
# 打印结果保留四位小数：
# x0 = 1.0000, y0 = 0.0000
# x1 = 1.1,y1 = 0.3459
# x2 = 1.2,y2 = 0.8666
# x3 = 1.3,y3 = 1.6072
# x4 = 1.4,y4 = 2.6203
# x5 = 1.5,y5 = 3.9676
# x6 = 1.6,y6 = 5.7209
# x7 = 1.7,y7 = 7.9638
# x8 = 1.8,y8 = 10.7935
# x9 = 1.9,y9 = 14.3229
# x10 = 2.0,y10 = 18.6829
# x11 = 2.1,y11 = 24.025
# x12 = 2.2,y12 = 30.5244
# x13 = 2.3,y13 = 38.3835
# x14 = 2.4,y14 = 47.8359
# x15 = 2.5,y15 = 59.151
# x16 = 2.6,y16 = 72.6389
# x17 = 2.7,y17 = 88.6566
# x18 = 2.8,y18 = 107.6143
# x19 = 2.9,y19 = 129.9833
# x20 = 3.0,y20 = 156.3048
# 验证得到标准差为 = 0.00025936026652007406
# 作图分析误差：

# %%
x , y =sp.symbols('x,y')
f =(1/x)*((y**2)+y)
a = 1
b = 3 
init = -2
exp = (x*2)/(1-2*x)
for n in [5,10,20]:
    print("N = ",n)
    X,Y = RuKu(f,a,b,init,n)
    E = Verf(X,Y,exp)
# Out:
# N =  5
# 打印结果保留四位小数：
# x0 = 1.0000, y0 = -1.0000
# x1 = 1.4,y1 = -1.0
# x2 = 1.8,y2 = -1.0
# x3 = 2.2,y3 = -1.0
# x4 = 2.6,y4 = -1.0
# x5 = 3.0,y5 = -1.0
# 验证得到标准差为 = 0.5227755257766837
# 作图分析误差：
# N =  10
# 打印结果保留四位小数：
# x0 = 1.0000, y0 = -1.0000
# x1 = 1.2,y1 = -1.0
# x2 = 1.4,y2 = -1.0
# x3 = 1.6,y3 = -1.0
# x4 = 1.8,y4 = -1.0
# x5 = 2.0,y5 = -1.0
# x6 = 2.2,y6 = -1.0
# x7 = 2.4,y7 = -1.0
# x8 = 2.6,y8 = -1.0
# x9 = 2.8,y9 = -1.0
# x10 = 3.0,y10 = -1.0
# 验证得到标准差为 = 0.48469327900760684
# 作图分析误差：
# N =  20
# 打印结果保留四位小数：
# x0 = 1.0000, y0 = -1.0000
# x1 = 1.1,y1 = -1.0
# x2 = 1.2,y2 = -1.0
# x3 = 1.3,y3 = -1.0
# x4 = 1.4,y4 = -1.0
# x5 = 1.5,y5 = -1.0
# x6 = 1.6,y6 = -1.0
# x7 = 1.7,y7 = -1.0
# x8 = 1.8,y8 = -1.0
# x9 = 1.9,y9 = -1.0
# x10 = 2.0,y10 = -1.0
# x11 = 2.1,y11 = -1.0
# x12 = 2.2,y12 = -1.0
# x13 = 2.3,y13 = -1.0
# x14 = 2.4,y14 = -1.0
# x15 = 2.5,y15 = -1.0
# x16 = 2.6,y16 = -1.0
# x17 = 2.7,y17 = -1.0
# x18 = 2.8,y18 = -1.0
# x19 = 2.9,y19 = -1.0
# x20 = 3.0,y20 = -1.0
# 验证得到标准差为 = 0.46561824297416116
# 作图分析误差：
